# %% [markdown]
# # 그래프 그리기!
#
# 1. 기본 라이브러리 & 설정

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('y-label')

plt.grid()  # 그래프 격자
plt.show()

# %%
print('hi')
# Out:
# hi
